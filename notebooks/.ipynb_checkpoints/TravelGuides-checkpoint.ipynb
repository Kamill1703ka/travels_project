# %%
pip install gliclass
# Out:
# Requirement already satisfied: gliclass in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (0.1.16)
# Requirement already satisfied: numpy<3.0.0,>=2.0.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from gliclass) (2.4.3)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from gliclass) (1.8.0)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from gliclass) (2.10.0)
# Collecting transformers<=4.57.3 (from gliclass)
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from scikit-learn<2.0.0,>=1.0.0->gliclass) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from scikit-learn<2.0.0,>=1.0.0->gliclass) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from scikit-learn<2.0.0,>=1.0.0->gliclass) (3.6.0)
# Requirement already satisfied: filelock in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from torch<3.0.0,>=2.0.0->gliclass) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from torch<3.0.0,>=2.0.0->gliclass) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from torch<3.0.0,>=2.0.0->gliclass) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from torch<3.0.0,>=2.0.0->gliclass) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from torch<3.0.0,>=2.0.0->gliclass) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from torch<3.0.0,>=2.0.0->gliclass) (2026.2.0)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers<=4.57.3->gliclass)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from transformers<=4.57.3->gliclass) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from transformers<=4.57.3->gliclass) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from transformers<=4.57.3->gliclass) (2026.2.28)
# Requirement already satisfied: requests in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from transformers<=4.57.3->gliclass) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from transformers<=4.57.3->gliclass) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from transformers<=4.57.3->gliclass) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from transformers<=4.57.3->gliclass) (4.67.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from sympy>=1.13.3->torch<3.0.0,>=2.0.0->gliclass) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from tqdm>=4.27->transformers<=4.57.3->gliclass) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from jinja2->torch<3.0.0,>=2.0.0->gliclass) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from requests->transformers<=4.57.3->gliclass) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from requests->transformers<=4.57.3->gliclass) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from requests->transformers<=4.57.3->gliclass) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\V\anaconda3\envs\tf_env\Lib\site-packages (from requests->transformers<=4.57.3->gliclass) (2026.2.25)
# Using cached transformers-4.57.3-py3-none-any.whl (12.0 MB)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Installing collected packages: huggingface-hub, transformers
#
#   Attempting uninstall: huggingface-hub
#
#     Found existing installation: huggingface_hub 1.6.0
#
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#     Uninstalling huggingface_hub-1.6.0:
#    ---------------------------------------- 0/2 [huggingface-hub]
#       Successfully uninstalled huggingface_hub-1.6.0
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#    ---------------------------------------- 0/2 [huggingface-hub]
#   Attempting uninstall: transformers
#    ---------------------------------------- 0/2 [huggingface-hub]
#     Found existing installation: transformers 5.3.0
#    ---------------------------------------- 0/2 [huggingface-hub]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#     Uninstalling transformers-5.3.0:
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#       Successfully uninstalled transformers-5.3.0
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    ---------------------------------------- 2/2 [transformers]
#
# Successfully installed huggingface-hub-0.36.2 transformers-4.57.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from transformers import AutoTokenizer
from gliclass import GLiClassModel, ZeroShotClassificationPipeline

# Модель и токенизатор
model_name = "knowledgator/gliclass-instruct-large-v1.0"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = GLiClassModel.from_pretrained(model_name, trust_remote_code=True)

# Zero-shot pipeline
pipeline = ZeroShotClassificationPipeline(
    model=model,
    tokenizer=tokenizer,
    classification_type="multi-label",
    device=-1  # CPU; для GPU: device=0
)

# Текст для классификации
text = "Что покушатьв Париже?"

# Классы
labels = ["Туризм", "Работа", "Учёба", "Еда", "Погода", "Общая информация"]

# Классификация
results = pipeline(text, labels, threshold=0.0)[0]

# Берем только класс с наивысшей вероятностью
best_label = max(results, key=lambda x: x["score"])["label"]

print(best_label)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:16<00:00, 16.67s/it]
# Еда
